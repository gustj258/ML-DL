# %%
import csv

# %%
f = open('age.csv')
data = csv.reader(f)

for row in data:
    print(row)
# Out:
# ['행정구역', '2019년02월_남_총인구수', '2019년02월_남_연령구간인구수', '2019년02월_남_0세', '2019년02월_여_총인구수', '2019년02월_여_연령구간인구수', '2019년02월_여_0세']
# ['서울특별시  (1100000000)', '4,773,605', '27,977', '27,977', '4,997,033', '25,761', '25,761']
# ['서울특별시 종로구 (1111000000)', '74,662', '318', '318', '78,218', '275', '275']
# ['서울특별시 종로구 청운효자동(1111051500)', '6,088', '27', '27', '6,922', '39', '39']
# ['서울특별시 종로구 사직동(1111053000)', '4,313', '19', '19', '5,271', '24', '24']
# ['서울특별시 종로구 삼청동(1111054000)', '1,328', '6', '6', '1,492', '3', '3']
# ['서울특별시 종로구 부암동(1111055000)', '4,839', '18', '18', '5,303', '16', '16']
# ['서울특별시 종로구 평창동(1111056000)', '8,859', '47', '47', '10,022', '34', '34']
# ['서울특별시 종로구 무악동(1111057000)', '3,953', '14', '14', '4,462', '6', '6']
# ['서울특별시 종로구 교남동(1111058000)', '4,987', '46', '46', '5,717', '51', '51']
# ['서울특별시 종로구 가회동(1111060000)', '2,060', '9', '9', '2,352', '5', '5']
# ['서울특별시 종로구 종로1.2.3.4가동(1111061500)', '4,372', '12', '12', '2,975', '6', '6']
# ...

# %%
if '서울특별시 구로구 신도림동(1153051000)' == row[0] :
    print(row)

# %%
print('신도림' in '서울특별시 구로구 신도림동(1153051000)')
# Out:
# True

# %%
print('1153' in '서울특별시 구로구 신도림동(1153051000)')
# Out:
# True

# %%
print('()' in '서울특별시 구로구 신도림동(1153051000)')
# Out:
# False

# %%
f = open('age.csv')
data = csv.reader(f)

for row in data :
    if '신도림' in row[0] :
        print(row)
# Out:
# ['서울특별시 구로구 신도림동(1153051000)', '18,245', '174', '174', '19,023', '152', '152']

# %%
import matplotlib.pyplot as plt

# %%
import csv

# %%
f = open('subwayfee.csv', 'rt', encoding='UTF8') #한글 번역 인코딩이 잘안될경우 
data = csv.reader(f)
 
for row in data :
    print(row)
# Out:
# ['\ufeff사용월', '노선ID', '노선번호', '노선명', '버스정류장ID', '버스정류장명', '승차승객수', '하차승객수']
# ['Jan-19', '11110897', '17', '0017번(청암동~이촌동)', '8501292', '청암자이아파트', '487', '8']
# ['Jan-19', '11110897', '17', '0017번(청암동~이촌동)', '9003185', '청암동강변삼성아파트', '1,679', '20']
# ['Jan-19', '11110897', '17', '0017번(청암동~이촌동)', '72983', '청심경로당', '3,190', '42']
# ['Jan-19', '11110897', '17', '0017번(청암동~이촌동)', '72984', '원효2동주민센터', '5,321', '124']
# ['Jan-19', '11110897', '17', '0017번(청암동~이촌동)', '72985', '산천동', '7,045', '219']
# ['Jan-19', '11110897', '17', '0017번(청암동~이촌동)', '72986', '신창동세방아파트', '6,459', '252']
# ['Jan-19', '11110897', '17', '0017번(청암동~이촌동)', '72987', '남이장군사당', '1,489', '1,617']
# ['Jan-19', '11110897', '17', '0017번(청암동~이촌동)', '72988', '새마을금고', '4,933', '3,165']
# ['Jan-19', '11110897', '17', '0017번(청암동~이촌동)', '33066', '용문시장', '5,402', '1,876']
# ['Jan-19', '11110897', '17', '0017번(청암동~이촌동)', '72990', '용산전자상가입구', '2,717', '1,032']
# ...

# %%
import pandas as pd

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table')
print(df)
# Out:
# [                                       Olympic Games
# 0                                        Main topics
# 1  Bids Boycotts Ceremonies Charter Host cities I...
# 2                                              Games
# 3  Summer Winter Youth African American Asian Eur...
# 4                                                vte,                                Unnamed: 0_level_0 Summer Games  \
#                                   Team (IOC code)            №
# 0                               Afghanistan (AFG)           14
# 1                                   Algeria (ALG)           13
# 2                                 Argentina (ARG)           24
# 3                                   Armenia (ARM)            6
# 4                         Australasia (ANZ) [ANZ]            2
# ..                                            ...          ...
# 148                          Zimbabwe (ZIM) [ZIM]           13
# 149      Independent Olympic Athletes (IOA) [IOA]            3
# ...

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/All-time_Olympic_Games_medal_table', header=0, index_col=0)
df[1]
# Out:
#                                              Summer Games  Summer Games.1  \
# Team (IOC code)                                         №             NaN
# Afghanistan (AFG)                                      14             0.0
# Algeria (ALG)                                          13             5.0
# Argentina (ARG)                                        24            21.0
# Armenia (ARM)                                           6             2.0
# ...                                                   ...             ...
# Zimbabwe (ZIM) [ZIM]                                   13             3.0
# Independent Olympic Athletes (IOA) [IOA]                3             1.0
# Independent Olympic Participants (IOP) [IOP]            1             0.0
# Mixed team (ZZX) [ZZX]                                  3             8.0
# Totals                                                 28          5116.0
#
#                                               Summer Games.2  Summer Games.3  \
# ...

# %%
summer = df[1].iloc[:,:5]
summer
# Out:
#                                              Summer Games  Summer Games.1  \
# Team (IOC code)                                         №             NaN
# Afghanistan (AFG)                                      14             0.0
# Algeria (ALG)                                          13             5.0
# Argentina (ARG)                                        24            21.0
# Armenia (ARM)                                           6             2.0
# ...                                                   ...             ...
# Zimbabwe (ZIM) [ZIM]                                   13             3.0
# Independent Olympic Athletes (IOA) [IOA]                3             1.0
# Independent Olympic Participants (IOP) [IOP]            1             0.0
# Mixed team (ZZX) [ZZX]                                  3             8.0
# Totals                                                 28          5116.0
#
#                                               Summer Games.2  Summer Games.3  \
# ...

# %%
summer.to_excel('하계올림픽메달.xlsx')

# %%
import numpy as np
